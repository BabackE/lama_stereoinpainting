# %%
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np

from depth_h5py_gen import *

# %load_ext autoreload
# %autoreload 2

data_root = "D:/dev/lama_stereoinpainting/docker/places/places_standard_dataset"
hdf5_file_path = f"{data_root}/train_large_places365standard_jpgs.hdf5"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_root = f"{data_root}/train"
copy_jpg_into_hdf5(train_root, hdf5_file_path)
# Out:
# Processing data_large/a/airfield with 5000 files.
# ...
# data_large/a/airfield:   0%|          | 0/5000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 train_root = f"{data_root}/train"
# ----> 2 copy_jpg_into_hdf5(train_root, hdf5_file_path)
#
# File d:\dev\lama_stereoinpainting\cse493g\depth_h5py_gen.py:61, in copy_jpg_into_hdf5(root_dir, hdf5_file_path)
#      59 file_path = os.path.join(dirpath, filename)
#      60 with open(file_path, "rb") as img_file:
# ---> 61     binary_data = img_file.read()
#      63 group.create_dataset(dataset_name, data=np.void(binary_data))
#      65 process_count+=1
#
# KeyboardInterrupt:

# %%
# Open the HDF5 file
hdf5_file = h5py.File(hdf5_file_path, 'r')

# List all groups and datasets
print("Listing all groups and datasets:")
list_all_groups_and_datasets(hdf5_file)
hdf5_file.close()

# Access a specific JPG
img_path = "/data_large/a/airfield/00002508.jpg"
rgb = cv2.cvtColor(cv2.imdecode(get_jpg_from_hdf5(hdf5_file_path,img_path),cv2.IMREAD_COLOR),cv2.COLOR_BGR2RGB)
plt.imshow(rgb)
plt.show()
# Out:
# Listing all groups and datasets:
# Group: /data_large
# Group: /data_large/a
# Group: /data_large/a/airfield
#   Dataset: /data_large/a/airfield/00000001.jpg
#   Dataset: /data_large/a/airfield/00000002.jpg
#   Dataset: /data_large/a/airfield/00000003.jpg
#   Dataset: /data_large/a/airfield/00000004.jpg
#   Dataset: /data_large/a/airfield/00000005.jpg
#   Dataset: /data_large/a/airfield/00000006.jpg
#   Dataset: /data_large/a/airfield/00000007.jpg
#   Dataset: /data_large/a/airfield/00000008.jpg
#   Dataset: /data_large/a/airfield/00000009.jpg
#   Dataset: /data_large/a/airfield/00000010.jpg
#   Dataset: /data_large/a/airfield/00000011.jpg
#   Dataset: /data_large/a/airfield/00000012.jpg
#   Dataset: /data_large/a/airfield/00000013.jpg
#   Dataset: /data_large/a/airfield/00000014.jpg
#   Dataset: /data_large/a/airfield/00000015.jpg
#   Dataset: /data_large/a/airfield/00000016.jpg
#   Dataset: /data_large/a/airfield/00000017.jpg
#   Dataset: /data_large/a/airfield/00000018.jpg
# ...
